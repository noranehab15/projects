# %% [markdown]
# <a href="https://colab.research.google.com/github/noranehab15/projects/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split , cross_val_score
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.metrics import r2_score,mean_squared_error , mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

# %%
df=pd.read_csv("/content/train (1).csv")

# %%
df
# Out:
#        ID        date  meals_served  kitchen_staff  temperature_C  \
# 0       0  2022-12-19           196             13      27.887273
# 1       1  2023-11-21           244             15      10.317872
# 2       4  2022-02-01           148             16      27.714300
# 3       5  2023-03-19           157             19      19.173902
# 4       6  2022-07-18           297             10      26.375233
# ..    ...         ...           ...            ...            ...
# 906  1044  2022-03-29           395             18      17.354199
# 907  1045  2022-11-27           483             11      24.912137
# 908  1046  2023-04-12           243             11      28.870945
# 909  1048  2022-02-14           406             10      19.061638
# 910  1049  2024-05-10           350              6      23.708015
#
#      humidity_percent  day_of_week  special_event  past_waste_kg  \
# 0           45.362854            0              0       7.740587
# ...

# %%
filter=df[df['special_event']==1]
filter
# Out:
#        ID        date  meals_served  kitchen_staff  temperature_C  \
# 7       9  2023-12-16           416             16      18.559591
# 17     20  2022-09-02           283              8      18.918301
# 23     26  2022-10-18           353             11      10.437900
# 40     43  2023-10-16           280             18      20.607422
# 48     51  2022-11-06           439              8      28.810694
# ..    ...         ...           ...            ...            ...
# 867  1003  2024-02-16           291             13      25.053641
# 868  1004  2022-08-30           346             11      18.981269
# 882  1019  2022-09-01           302             18      25.138454
# 891  1028  2023-12-01           281             18      28.704798
# 896  1033  2022-09-10           297             10      10.854694
#
#      humidity_percent  day_of_week  special_event  past_waste_kg  \
# 7           75.786502            5              1      34.599442
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                911 non-null    int64
#  1   date              911 non-null    object
#  2   meals_served      911 non-null    int64
#  3   kitchen_staff     911 non-null    int64
#  4   temperature_C     911 non-null    float64
#  5   humidity_percent  911 non-null    float64
#  6   day_of_week       911 non-null    int64
#  7   special_event     911 non-null    int64
#  8   past_waste_kg     911 non-null    float64
#  9   staff_experience  747 non-null    object
#  10  waste_category    911 non-null    object
#  11  food_waste_kg     911 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 85.5+ KB

# %%
df.describe()
# Out:
#                 ID  meals_served  kitchen_staff  temperature_C  \
# count   911.000000    911.000000     911.000000     911.000000
# mean    528.327113    375.405049      11.900110      22.189280
# std     305.072794    502.812717       4.285153       8.922389
# min       0.000000    100.000000       5.000000     -10.372207
# 25%     266.000000    211.000000       8.000000      15.684585
# 50%     531.000000    306.000000      12.000000      22.115040
# 75%     795.500000    407.000000      15.000000      28.804294
# max    1049.000000   4730.000000      19.000000      60.000000
#
#        humidity_percent  day_of_week  special_event  past_waste_kg  \
# count        911.000000   911.000000     911.000000     911.000000
# mean          60.761313     3.014270       0.085620      27.015691
# std           17.330821     2.009542       0.279956      12.774223
# min           30.121111     0.000000       0.000000       5.008394
# ...

# %%
df.skew(numeric_only=True)
# Out:
# ID                 -0.015749
# meals_served        6.581128
# kitchen_staff       0.020202
# temperature_C       0.111854
# humidity_percent   -0.093234
# day_of_week        -0.008186
# special_event       2.966833
# past_waste_kg       0.016268
# food_waste_kg       4.990900
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
dtypes=df.dtypes
uniques=df.nunique()
pd.concat([dtypes,uniques],axis=1)
# Out:
#                         0    1
# ID                  int64  911
# date               object  867
# meals_served        int64  373
# kitchen_staff       int64   15
# temperature_C     float64  892
# humidity_percent  float64  867
# day_of_week         int64    7
# special_event       int64    2
# past_waste_kg     float64  867
# staff_experience   object    4
# waste_category     object    5
# food_waste_kg     float64  867

# %%
df.drop(columns=["ID","date"],inplace=True)

# %%
df
# Out:
#      meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0             196             13      27.887273         45.362854
# 1             244             15      10.317872         64.430475
# 2             148             16      27.714300         69.046113
# 3             157             19      19.173902         46.292823
# 4             297             10      26.375233         79.741064
# ..            ...            ...            ...               ...
# 906           395             18      17.354199         45.138435
# 907           483             11      24.912137         59.485091
# 908           243             11      28.870945         70.508404
# 909           406             10      19.061638         55.286642
# 910           350              6      23.708015         51.351286
#
#      day_of_week  special_event  past_waste_kg staff_experience  \
# 0              0              0       7.740587     intermediate
# ...

# %%
numerical_cols = df.select_dtypes(include=['number']).columns

Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_cleaned = df[~((df[numerical_cols] < lower_bound) | (df[numerical_cols] > upper_bound)).any(axis=1)]

df.shape, df_cleaned.shape
# Out:
# ((911, 10), (793, 10))

# %%
df.isnull().sum()
# Out:
# meals_served          0
# kitchen_staff         0
# temperature_C         0
# humidity_percent      0
# day_of_week           0
# special_event         0
# past_waste_kg         0
# staff_experience    164
# waste_category        0
# food_waste_kg         0
# dtype: int64

# %%
pd.DataFrame({"Null %":df.isnull().sum()/df.shape[0]*100,"Null count":df.isnull().sum()})
# Out:
#                      Null %  Null count
# meals_served       0.000000           0
# kitchen_staff      0.000000           0
# temperature_C      0.000000           0
# humidity_percent   0.000000           0
# day_of_week        0.000000           0
# special_event      0.000000           0
# past_waste_kg      0.000000           0
# staff_experience  18.002195         164
# waste_category     0.000000           0
# food_waste_kg      0.000000           0

# %%
df["staff_experience"].value_counts()
# Out:
# staff_experience
# Beginner        191
# Intermediate    186
# EXPERT          186
# intermediate    184
# Name: count, dtype: int64

# %%
display(df["waste_category"].value_counts())
# Out:
# waste_category
# MEAT          210
# dairy         180
# Vegetables    176
# GRAINS        176
# MeAt          169
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["staff_experience"]=le.fit_transform(df["staff_experience"])
df["waste_category"]=le.fit_transform(df["waste_category"])
df
# Out:
#      meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0             196             13      27.887273         45.362854
# 1             244             15      10.317872         64.430475
# 2             148             16      27.714300         69.046113
# 3             157             19      19.173902         46.292823
# 4             297             10      26.375233         79.741064
# ..            ...            ...            ...               ...
# 906           395             18      17.354199         45.138435
# 907           483             11      24.912137         59.485091
# 908           243             11      28.870945         70.508404
# 909           406             10      19.061638         55.286642
# 910           350              6      23.708015         51.351286
#
#      day_of_week  special_event  past_waste_kg  staff_experience  \
# 0              0              0       7.740587                 3
# ...

# %%
x=df.drop(columns=["food_waste_kg"])
y=df["food_waste_kg"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression,SGDRegressor

# %%
model1=LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
x_test
# Out:
#      meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 704           147             18      15.976383         63.124162
# 760           164             18      16.634685         47.468655
# 545           339              7      18.494437         72.227539
# 367           326              5      30.536018         81.248160
# 361           157              6      22.209853         80.750973
# ..            ...            ...            ...               ...
# 705           180             10      33.816216         77.205020
# 643           358             19      24.616768         48.792376
# 300           421             18      60.000000         44.079207
# 7             416             16      18.559591         75.786502
# 244          1380              5      13.742599         47.550905
#
#      day_of_week  special_event  past_waste_kg  staff_experience  \
# 704            4              0      41.924846                 2
# ...

# %%
y_pred=model1.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.7922002843999811

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 143.27777659073828

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
model2=LinearRegression()
model2.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model2.predict(x_test_scaled)
r2_score(y_test,y_pred)
# Out:
# 0.7922002843999822

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 143.27777659073752

# %%
sgd=SGDRegressor(eta0=0.01,learning_rate="constant")

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor(learning_rate='constant')

# %%
y_pred=sgd.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# -3.0052724782809213e+27

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.0721335324935792e+30

# %%
sgd1=SGDRegressor(eta0=0.01,learning_rate="constant")

# %%
sgd1.fit(x_train_scaled,y_train)
# Out:
# SGDRegressor(learning_rate='constant')

# %%
y_pred=sgd1.predict(x_test_scaled)
r2_score(y_test,y_pred)
# Out:
# 0.7871857996139335

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 146.73526077842556

# %%
df2 =pd.read_csv("test.csv")
df3=pd.read_csv("test.csv")
df2
# Out:
#        ID        date  meals_served  kitchen_staff  temperature_C  \
# 0       0  2022-12-19           196             13      27.887273
# 1       1  2023-11-21           244             15      10.317872
# 2       4  2022-02-01           148             16      27.714300
# 3       5  2023-03-19           157             19      19.173902
# 4       6  2022-07-18           297             10      26.375233
# ..    ...         ...           ...            ...            ...
# 906  1044  2022-03-29           395             18      17.354199
# 907  1045  2022-11-27           483             11      24.912137
# 908  1046  2023-04-12           243             11      28.870945
# 909  1048  2022-02-14           406             10      19.061638
# 910  1049  2024-05-10           350              6      23.708015
#
#      humidity_percent  day_of_week  special_event  past_waste_kg  \
# 0           45.362854            0              0       7.740587
# ...

# %%
df2.drop(columns=["ID","date","day_of_week"],inplace=True)
df2
# Out:
#      meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0             196             13      27.887273         45.362854
# 1             244             15      10.317872         64.430475
# 2             148             16      27.714300         69.046113
# 3             157             19      19.173902         46.292823
# 4             297             10      26.375233         79.741064
# ..            ...            ...            ...               ...
# 906           395             18      17.354199         45.138435
# 907           483             11      24.912137         59.485091
# 908           243             11      28.870945         70.508404
# 909           406             10      19.061638         55.286642
# 910           350              6      23.708015         51.351286
#
#      special_event  past_waste_kg staff_experience waste_category
# 0                0       7.740587     intermediate          dairy
# ...

# %%
df2["temperature_C"].value_counts()
# Out:
# temperature_C
# -10.000000    12
#  60.000000     9
#  27.887273     1
#  21.981973     1
#  31.145476     1
#               ..
#  28.915895     1
#  22.022596     1
#  11.782007     1
#  16.214506     1
#  23.708015     1
# Name: count, Length: 892, dtype: int64

# %%
df["temperature_C"] = df["temperature_C"].apply(lambda x: 22.34 if x <= 9 else x)

# %%
def lower_case_columns(df2, cols):
    df2[cols] = df2[cols].astype(str).apply(lambda x: x.str.lower())
    return df2

df2 = lower_case_columns(df2, ["waste_category"])

display(df2["waste_category"].value_counts())
# Out:
# waste_category
# meat          379
# dairy         180
# vegetables    176
# grains        176
# Name: count, dtype: int64

# %%
df2["staff_experience"] = df2["staff_experience"].replace("intermediate", "Intermediate")
display(df2["staff_experience"].value_counts())
# Out:
# staff_experience
# Intermediate    370
# Beginner        191
# EXPERT          186
# Name: count, dtype: int64

# %%
df2["staff_experience"] = df2["staff_experience"].fillna(df2["staff_experience"].mode()[0])
pd.DataFrame({"Null %":(df2.isnull().sum()/df2.shape[0]*100),"Null count":df2.isnull().sum()}).T
# Out:
#             meals_served  kitchen_staff  temperature_C  humidity_percent  \
# Null %               0.0            0.0            0.0               0.0
# Null count           0.0            0.0            0.0               0.0
#
#             special_event  past_waste_kg  staff_experience  waste_category
# Null %                0.0            0.0               0.0             0.0
# Null count            0.0            0.0               0.0             0.0

# %%
X=df2
X
# Out:
#      meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0             196             13      27.887273         45.362854
# 1             244             15      10.317872         64.430475
# 2             148             16      27.714300         69.046113
# 3             157             19      19.173902         46.292823
# 4             297             10      26.375233         79.741064
# ..            ...            ...            ...               ...
# 906           395             18      17.354199         45.138435
# 907           483             11      24.912137         59.485091
# 908           243             11      28.870945         70.508404
# 909           406             10      19.061638         55.286642
# 910           350              6      23.708015         51.351286
#
#      special_event  past_waste_kg staff_experience waste_category
# 0                0       7.740587     Intermediate          dairy
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
x["waste_category"] = encoder.fit_transform(x["waste_category"])
x["waste_category"] = x["waste_category"].map(lambda x: encoder.transform([x])[0] if x in encoder.classes_ else -1)

# %%
mean_of_target=df["food_waste_kg"].mean()
vars_of_target=df["food_waste_kg"].var()
std_of_target=df["food_waste_kg"].std()
print(f"Mean of Target data: {mean_of_target}\nStanderd deviation of Target data: {std_of_target}\nVariance of Target data : {vars_of_target}")
# Out:
# Mean of Target data: 44.842690535696
# Standerd deviation of Target data: 27.93436623705769
# Variance of Target data : 780.3288170660686

# %%
lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred_test = lr.predict(x)
y_pred_test.mean()
y_pred_test.std()
y_pred_test.var()
print(f"Mean of Prediction data: {y_pred_test.mean()}\nStanderd deviation of Prediction data: {y_pred_test.std()}\nVariance of Prediction data : {y_pred_test.var()}")
# Out:
# Mean of Prediction data: 44.842690535696
# Standerd deviation of Prediction data: 25.640370812618855
# Variance of Prediction data : 657.4286154085969

# %%
x["waste_category"]=encoder.transform(x["waste_category"])
x
# Out:
#      meals_served  kitchen_staff  temperature_C  humidity_percent  \
# 0             196             13      27.887273         45.362854
# 1             244             15      10.317872         64.430475
# 2             148             16      27.714300         69.046113
# 3             157             19      19.173902         46.292823
# 4             297             10      26.375233         79.741064
# ..            ...            ...            ...               ...
# 906           395             18      17.354199         45.138435
# 907           483             11      24.912137         59.485091
# 908           243             11      28.870945         70.508404
# 909           406             10      19.061638         55.286642
# 910           350              6      23.708015         51.351286
#
#      day_of_week  special_event  past_waste_kg  staff_experience  \
# 0              0              0       7.740587                 3
# ...

# %%
df.to_csv("processed_data.csv", index=False)
